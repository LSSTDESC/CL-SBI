# %%
### start with the MCMC process, then I'll add in the cosmo part later

# %%
conda list
# Out:
# # packages in environment at /global/homes/e/erinbari/.conda/envs/clmmenv:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# alabaster                 0.7.12                   pypi_0    pypi
# argon2-cffi               21.3.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# arviz                     0.12.1             pyhd8ed1ab_1    conda-forge
# astropy                   5.1                      pypi_0    pypi
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     21.4.0                   pypi_0    pypi
# babel                     2.10.3                   pypi_0    pypi
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1                   pypi_0    pypi
# binutils_impl_linux-64    2.36.1               h193b22a_2    conda-forge
# binutils_linux-64         2.36                hf3e587d_10    conda-forge
# bleach                    5.0.1                    pypi_0    pypi
# brotli                    1.0.9                h166bdaf_7    conda-forge
# brotli-bin                1.0.9                h166bdaf_7    conda-forge
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.18.1               h7f98852_0    conda-forge
# ca-certificates           2022.6.15            ha878542_0    conda-forge
# camb                      1.3.5           py310h8c77ee3_0    conda-forge
# certifi                   2022.6.15       py310hff52083_0    conda-forge
# cffi                      1.15.1                   pypi_0    pypi
# cftime                    1.6.1           py310hde88566_0    conda-forge
# chainconsumer             0.33.0                   pypi_0    pypi
# charset-normalizer        2.1.0                    pypi_0    pypi
# corner                    2.2.1              pyhd8ed1ab_0    conda-forge
# curl                      7.83.1               h7bff187_0    conda-forge
# cycler                    0.11.0             pyhd8ed1ab_0    conda-forge
# debugpy                   1.6.2                    pypi_0    pypi
# decorator                 5.1.1              pyhd3eb1b0_0
# defusedxml                0.7.1                    pypi_0    pypi
# docutils                  0.17.1                   pypi_0    pypi
# easyquery                 0.4.0                    pypi_0    pypi
# emcee                     3.1.2              pyhd8ed1ab_0    conda-forge
# entrypoints               0.4                      pypi_0    pypi
# executing                 0.8.3              pyhd3eb1b0_0
# fast-pt                   3.1.0              pyh9f0ad1d_0    conda-forge
# fast3tree                 0.4.0                    pypi_0    pypi
# fastjsonschema            2.15.3                   pypi_0    pypi
# fftw                      3.3.10          nompi_h77c792f_102    conda-forge
# firefox                   102.0                h27087fc_0    conda-forge
# fofcatalogmatching        0.1.0                    pypi_0    pypi
# fonttools                 4.34.4          py310h5764c6d_0    conda-forge
# freetype                  2.10.4               h0708190_1    conda-forge
# gcc_impl_linux-64         9.4.0               h03d3576_16    conda-forge
# gcc_linux-64              9.4.0               h391b98a_10    conda-forge
# gcr                       0.9.2                    pypi_0    pypi
# gcrcatalogs               1.4.0                    pypi_0    pypi
# gfortran_impl_linux-64    9.4.0               h0003116_16    conda-forge
# gfortran_linux-64         9.4.0               hf0ab688_10    conda-forge
# giflib                    5.2.1                h36c2ea0_2    conda-forge
# gmp                       6.2.1                h58526e2_0    conda-forge
# gmpy2                     2.1.2           py310h92f7908_0    conda-forge
# gsl                       2.7                  he838d99_0    conda-forge
# h5py                      3.7.0                    pypi_0    pypi
# hdf4                      4.2.15               h10796ff_3    conda-forge
# hdf5                      1.12.1          nompi_h2386368_104    conda-forge
# healpy                    1.15.2                   pypi_0    pypi
# idna                      3.3                      pypi_0    pypi
# imagesize                 1.4.1                    pypi_0    pypi
# iniconfig                 1.1.1                    pypi_0    pypi
# ipykernel                 6.15.1                   pypi_0    pypi
# ipython                   8.4.0           py310h06a4308_0
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                7.7.1                    pypi_0    pypi
# jedi                      0.18.1          py310h06a4308_1
# jinja2                    3.1.2                    pypi_0    pypi
# jpeg                      9e                   h166bdaf_2    conda-forge
# jsonschema                4.7.2                    pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            7.3.4                    pypi_0    pypi
# jupyter-console           6.4.4                    pypi_0    pypi
# jupyter-core              4.11.1                   pypi_0    pypi
# jupyterlab-pygments       0.2.2                    pypi_0    pypi
# jupyterlab-widgets        1.1.1                    pypi_0    pypi
# kernel-headers_linux-64   2.6.32              he073ed8_15    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.3           py310hbf28c38_0    conda-forge
# krb5                      1.19.3               h3790be6_0    conda-forge
# lcms2                     2.12                 hddcbb42_0    conda-forge
# ld_impl_linux-64          2.36.1               hea4e1c9_2    conda-forge
# libblas                   3.9.0           15_linux64_openblas    conda-forge
# libbrotlicommon           1.0.9                h166bdaf_7    conda-forge
# libbrotlidec              1.0.9                h166bdaf_7    conda-forge
# libbrotlienc              1.0.9                h166bdaf_7    conda-forge
# libcblas                  3.9.0           15_linux64_openblas    conda-forge
# libcurl                   7.83.1               h7bff187_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 h516909a_1    conda-forge
# libffi                    3.3                  he6710b0_2
# libgcc-devel_linux-64     9.4.0               hd854feb_16    conda-forge
# libgcc-ng                 12.1.0              h8d9b700_16    conda-forge
# libgfortran-ng            12.1.0              h69a702a_16    conda-forge
# libgfortran5              12.1.0              hdcd56e2_16    conda-forge
# libgomp                   12.1.0              h8d9b700_16    conda-forge
# liblapack                 3.9.0           15_linux64_openblas    conda-forge
# libnetcdf                 4.8.1           nompi_h329d8a1_102    conda-forge
# libnghttp2                1.47.0               h727a467_0    conda-forge
# libopenblas               0.3.20          pthreads_h78a6416_0    conda-forge
# libpng                    1.6.37               h21135ba_2    conda-forge
# libsanitizer              9.4.0               h79bfe98_16    conda-forge
# libssh2                   1.10.0               ha56f1ee_2    conda-forge
# libstdcxx-ng              12.1.0              ha89aaad_16    conda-forge
# libtiff                   4.2.0                hf544144_3    conda-forge
# libuuid                   1.0.3                h7f8727e_2
# libwebp                   1.2.0                h3452ae3_0    conda-forge
# libwebp-base              1.2.0                h7f98852_2    conda-forge
# libzip                    1.9.2                hc869a4a_0    conda-forge
# libzlib                   1.2.12               h166bdaf_2    conda-forge
# lz4-c                     1.9.3                h9c3ff4c_1    conda-forge
# markupsafe                2.1.1                    pypi_0    pypi
# matplotlib-base           3.5.2           py310h5701ce4_0    conda-forge
# matplotlib-inline         0.1.3                    pypi_0    pypi
# mistune                   0.8.4                    pypi_0    pypi
# mock                      4.0.3           py310hff52083_3    conda-forge
# mpc                       1.2.1                h9f54685_0    conda-forge
# mpfr                      4.1.0                h9202a9a_1    conda-forge
# mpmath                    1.2.1              pyhd8ed1ab_0    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# nbclient                  0.6.6                    pypi_0    pypi
# nbconvert                 6.5.0                    pypi_0    pypi
# nbformat                  5.4.0                    pypi_0    pypi
# ncurses                   6.3                  h5eee18b_3
# nest-asyncio              1.5.5                    pypi_0    pypi
# netcdf4                   1.6.0           nompi_py310h947f774_100    conda-forge
# notebook                  6.4.12                   pypi_0    pypi
# numexpr                   2.8.3                    pypi_0    pypi
# numpy                     1.23.1          py310h53a5b5f_0    conda-forge
# openssl                   1.1.1q               h166bdaf_0    conda-forge
# packaging                 21.3               pyhd8ed1ab_0    conda-forge
# pandas                    1.4.3                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.3              pyhd3eb1b0_0
# patsy                     0.5.2                    pypi_0    pypi
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    9.0.1           py310h22f2fdc_0
# pip                       22.1.2          py310h06a4308_0
# pluggy                    1.0.0                    pypi_0    pypi
# prometheus-client         0.14.1                   pypi_0    pypi
# prompt-toolkit            3.0.30                   pypi_0    pypi
# psutil                    5.9.1                    pypi_0    pypi
# ptyprocess                0.7.0              pyhd3eb1b0_2
# pure_eval                 0.2.2              pyhd3eb1b0_0
# py                        1.11.0                   pypi_0    pypi
# pyarrow                   8.0.0                    pypi_0    pypi
# pyccl                     2.5.0           py310h6d2109b_0    conda-forge
# pycparser                 2.21                     pypi_0    pypi
# pyerfa                    2.0.0.1                  pypi_0    pypi
# pygments                  2.12.0                   pypi_0    pypi
# pyparsing                 3.0.9              pyhd8ed1ab_0    conda-forge
# pyrsistent                0.18.1                   pypi_0    pypi
# pytest                    7.1.2                    pypi_0    pypi
# python                    3.10.4               h12debd9_0
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python_abi                3.10                    2_cp310    conda-forge
# pytz                      2022.1             pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0             py310h5764c6d_4    conda-forge
# pyzmq                     23.2.0                   pypi_0    pypi
# qtconsole                 5.3.1                    pypi_0    pypi
# qtpy                      2.1.0                    pypi_0    pypi
# readline                  8.1.2                h7f8727e_1
# requests                  2.28.1                   pypi_0    pypi
# scipy                     1.8.1           py310h7612f91_0    conda-forge
# send2trash                1.8.0                    pypi_0    pypi
# setuptools                61.2.0          py310h06a4308_0
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# snowballstemmer           2.2.0                    pypi_0    pypi
# soupsieve                 2.3.2.post1              pypi_0    pypi
# sphinx                    5.0.2                    pypi_0    pypi
# sphinx-rtd-theme          1.0.0                    pypi_0    pypi
# sphinxcontrib-applehelp   1.0.2                    pypi_0    pypi
# sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
# sphinxcontrib-htmlhelp    2.0.0                    pypi_0    pypi
# sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
# sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
# sphinxcontrib-serializinghtml 1.1.5                    pypi_0    pypi
# sqlite                    3.38.5               hc218d9a_0
# stack-data                0.3.0                    pypi_0    pypi
# stack_data                0.2.0              pyhd3eb1b0_0
# statsmodels               0.13.2                   pypi_0    pypi
# sympy                     1.10.1          py310hff52083_0    conda-forge
# sysroot_linux-64          2.12                he073ed8_15    conda-forge
# terminado                 0.15.0                   pypi_0    pypi
# tinycss2                  1.1.1                    pypi_0    pypi
# tk                        8.6.12               h1ccaba5_0
# tomli                     2.0.1                    pypi_0    pypi
# tornado                   6.2                      pypi_0    pypi
# traitlets                 5.3.0                    pypi_0    pypi
# typing_extensions         4.3.0              pyha770c72_0    conda-forge
# tzdata                    2022a                hda174b7_0
# unicodedata2              14.0.0          py310h5764c6d_1    conda-forge
# urllib3                   1.26.10                  pypi_0    pypi
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1                    pypi_0    pypi
# wheel                     0.37.1             pyhd3eb1b0_0
# widgetsnbextension        3.6.1                    pypi_0    pypi
# xarray                    2022.6.0           pyhd8ed1ab_1    conda-forge
# xarray-einstats           0.3.0              pyhd8ed1ab_0    conda-forge
# xz                        5.2.5                h7f8727e_1
# yaml                      0.2.5                h7f98852_2    conda-forge
# zlib                      1.2.12               h7f8727e_2
# zstd                      1.5.0                ha95c52a_0    conda-forge
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# emcee, chainconsumer, and corner already installed

# %%
import numpy as np
import emcee
import matplotlib.pyplot as plt
from chainconsumer import ChainConsumer
import corner
from tqdm import tqdm

# %%
# plot settings
import matplotlib as mpl

fontsize = 18
rcparams = {}
rcparams['figure.figsize'] = (10, 6)
rcparams['axes.labelsize'] = fontsize
rcparams['legend.fontsize'] = fontsize-4
rcparams['axes.titlesize'] = fontsize
rcparams['axes.linewidth'] = 2
rcparams['axes.grid'] = True
for axis in ['x', 'y']:
    rcparams['%stick.labelsize' % axis] = fontsize-2
    rcparams['%stick.direction' % axis] = 'in'
    rcparams['%stick.major.size' % axis] = 5.5
    rcparams['%stick.minor.size' % axis] =  3.5
    rcparams['%stick.major.width' % axis] = 2
    rcparams['%stick.minor.width' % axis] = 1.5
rcparams['xtick.top'] = True
rcparams['ytick.right'] = True

# set up the plotting params
for key in rcparams: mpl.rcParams[key] = rcparams[key]

# %%
# NOW GENERATE THE MOCK DATA!!!!!

# %%
def install_clmm_pipeline(upgrade=False):
    import sys
    try:
        import clmm
        import cluster_toolkit
        installed = True
    except ImportError:
        installed = False
    if not upgrade:
        print('clmm is already installed and upgrade is False')
    else:
        # !{sys.executable} -m pip install --user --upgrade git+https://github.com/tmcclintock/cluster_toolkit.git
        # !{sys.executable} -m pip install --user --upgrade git+https://github.com/LSSTDESC/CLMM
install_clmm_pipeline(upgrade=True)
# Out:
# Collecting git+https://github.com/tmcclintock/cluster_toolkit.git
#   Cloning https://github.com/tmcclintock/cluster_toolkit.git to /tmp/pip-req-build-iozpaf0o
#   Running command git clone --filter=blob:none --quiet https://github.com/tmcclintock/cluster_toolkit.git /tmp/pip-req-build-iozpaf0o
#   Resolved https://github.com/tmcclintock/cluster_toolkit.git to commit 7bbc4264012e6f1e9344c295e841bbcdba9bdb6a
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       ln: invalid option -- 'h'
#       Try 'ln --help' for more information.
#       Traceback (most recent call last):
#         File "/tmp/pip-req-build-iozpaf0o/setup.py", line 11, in <module>
#           cflags = subprocess.check_output(['gsl-config', '--cflags'], universal_newlines=True).split()
#         File "/global/homes/e/erinbari/.conda/envs/clmmenv/lib/python3.10/subprocess.py", line 420, in check_output
#           return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#         File "/global/homes/e/erinbari/.conda/envs/clmmenv/lib/python3.10/subprocess.py", line 501, in run
#           with Popen(*popenargs, **kwargs) as process:
#         File "/global/homes/e/erinbari/.conda/envs/clmmenv/lib/python3.10/subprocess.py", line 966, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/global/homes/e/erinbari/.conda/envs/clmmenv/lib/python3.10/subprocess.py", line 1842, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'gsl-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-req-build-iozpaf0o/setup.py", line 14, in <module>
#           raise Exception("Error: must have GSL installed and gsl-config working")
#       Exception: Error: must have GSL installed and gsl-config working
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting git+https://github.com/LSSTDESC/CLMM
#   Cloning https://github.com/LSSTDESC/CLMM to /tmp/pip-req-build-09pycl8s
#   Running command git clone --filter=blob:none --quiet https://github.com/LSSTDESC/CLMM /tmp/pip-req-build-09pycl8s
#   Resolved https://github.com/LSSTDESC/CLMM to commit de22c0cf9cd4ab93965cc5111f134a8afa94320b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: astropy>=4.0 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from clmm==1.3.4) (5.1)
# Requirement already satisfied: numpy in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from clmm==1.3.4) (1.23.1)
# Requirement already satisfied: scipy in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from clmm==1.3.4) (1.8.1)
# Requirement already satisfied: healpy in ./.conda/envs/clmmenv/lib/python3.10/site-packages/healpy-1.15.2-py3.10-linux-x86_64.egg (from clmm==1.3.4) (1.15.2)
# Requirement already satisfied: pyerfa>=2.0 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from astropy>=4.0->clmm==1.3.4) (2.0.0.1)
# Requirement already satisfied: packaging>=19.0 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from astropy>=4.0->clmm==1.3.4) (21.3)
# Requirement already satisfied: PyYAML>=3.13 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from astropy>=4.0->clmm==1.3.4) (6.0)
# Requirement already satisfied: matplotlib in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from healpy->clmm==1.3.4) (3.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from packaging>=19.0->astropy>=4.0->clmm==1.3.4) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from matplotlib->healpy->clmm==1.3.4) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from matplotlib->healpy->clmm==1.3.4) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from matplotlib->healpy->clmm==1.3.4) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from matplotlib->healpy->clmm==1.3.4) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from matplotlib->healpy->clmm==1.3.4) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/clmmenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->healpy->clmm==1.3.4) (1.16.0)

# %%
import clmm
import clmm.dataops as da
import clmm.galaxycluster as gc
import clmm.theory as theory
from clmm import Cosmology

# %%
clmm.__version__
# Out:
# '1.3.4'

# %%
from clmm.support import mock_data as mock

# %%
np.random.seed(72)

# %%
mock_cosmo = Cosmology(H0 = 70.0, Omega_dm0 = 0.27 - 0.045, Omega_b0 = 0.045, Omega_k0 = 0.0)

# %%
### define a mock galaxy cluster:
cosmo = mock_cosmo
cluster_id = "cluster_x"
cluster_m = 1.e15 # M200,m [Msun]
cluster_z = 0.3
src_z = 0.8
concentration = 4
ngals = 10000
cluster_ra = 20.0
cluster_dec = 30.0

# %%
ideal_data = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration,
                                          cosmo, src_z, ngals=ngals, cluster_ra=cluster_ra, cluster_dec=cluster_dec)

# %%
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, ideal_data)

# %%
gc_object.save('mock_mcmc.pkl')

# %%
cl = clmm.GalaxyCluster.load('mock_mcmc.pkl')
print("Cluster info = ID:", cl.unique_id, "; ra:", cl.ra, "; dec:", cl.dec,
      "; z_l :", cl.z)
print("The number of source galaxies is :", len(cl.galcat))

ra_l = cl.ra
dec_l = cl.dec
z = cl.z
e1 = cl.galcat['e1']
e2 = cl.galcat['e2']
ra_s = cl.galcat['ra']
dec_s = cl.galcat['dec']
z_s = cl.galcat['z']
# Out:
# Cluster info = ID: cluster_x ; ra: 20.0 ; dec: 30.0 ; z_l : 0.3
# The number of source galaxies is : 10000

# %%
# then visualize distribution of galaxies on sky!

fsize = 15

fig = plt.figure(figsize=(10, 6))
hb = fig.gca().hexbin(ra_s, dec_s, gridsize=50)

cb = fig.colorbar(hb)
cb.set_label('Number of sources in bin', fontsize=fsize)

plt.gca().set_xlabel(r'$\Delta RA$', fontsize=fsize)
plt.gca().set_ylabel(r'$\Delta Dec$', fontsize=fsize)
plt.gca().set_title('Source Galaxies', fontsize=fsize)

plt.show()
# Out:
# /tmp/ipykernel_65332/3372700394.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = fig.colorbar(hb)

# %%
# computing shear:

# clmm.dataops.compute_tangential_and_cross_components calculates the tangential and cross shears
# for each source galaxy in the cluster.

theta, g_t, g_x = da.compute_tangential_and_cross_components(ra_l, dec_l, ra_s, dec_s, e1, e2)

# %%
# visualize shear at each location:

fig = plt.figure(figsize=(10, 6))

fig.gca().loglog(theta, g_t, '.')
plt.ylabel("reduced shear", fontsize=fsize)
plt.xlabel("angular distance [rad]", fontsize=fsize)
# Out:
# Text(0.5, 0, 'angular distance [rad]')

# %%
# radially binning the data

### going to compare results under 2 different binning def's

# *** Note binning would cause fitted mass to be slightly larger than input 
# mass. The reason is that g(r), the tangential reduced shear along cluster 
# radius, is a convex function -- the function value after binning would be
# larger, but the bias becomes smaller as bin number increases.


bin_edges = da.make_bins(0.01, 3.7, 50)

# %%
# clmm.dataops.make_radial_profile evaluates the average shear of the galaxy
# catalog in bins of radius.

res = da.make_radial_profile(
    [g_t, g_x, z_s], theta, "radians", "Mpc", bins=bin_edges, cosmo=cosmo, z_lens=z, include_empty_bins=False)

# %%
res_with_empty = da.make_radial_profile(
    [g_t, g_x, z_s], theta, "radians", "Mpc", bins=1000, cosmo=cosmo, z_lens=z, include_empty_bins=True)
# this is the default behavior
res_without_empty = da.make_radial_profile(
    [g_t, g_x, z_s], theta, "radians", "Mpc", bins=1000, cosmo=cosmo, z_lens=z, include_empty_bins=False)
res_with_empty['n_src'].size, res_without_empty['n_src'].size
# Out:
# (1000, 899)

# %%
gt_profile = res['p_0']
r = res['radius']
z = res['p_2']

# %%
# visualize radially-binned shear

fig = plt.figure(figsize=(10, 6))
fig.gca().loglog(r1, gt_profile, '.', label='50 bins')
plt.gca().set_title(r'Binned shear of source galaxies', fontsize=fsize)
plt.gca().set_xlabel(r'$r\;[Mpc]$', fontsize=fsize)
plt.gca().set_ylabel(r'$g_t$', fontsize=fsize)
# Out:
# Text(0, 0.5, '$g_t$')

# %%
# can also use make_radial_profile directly! on a clmm.GalaxyCluster object

cl.compute_tangential_and_cross_components() # You need to add the shear components first
cl.make_radial_profile("Mpc", bins=1000, cosmo=cosmo, include_empty_bins=False)
pass
# Out:
# /global/homes/e/erinbari/.local/lib/python3.10/site-packages/clmm/galaxycluster.py:520: UserWarning: overwriting profile table.
#   warnings.warn(f'overwriting {table_name} table.')

# %%
for n in cl.profile.colnames: cl.profile[n].format = "%6.3e"
cl.profile.pprint(max_width=-1)
# Out:
# radius_min   radius  radius_max     gt      gt_err      gx       gx_err      z       z_err     n_src
# ---------- --------- ---------- --------- --------- ---------- --------- --------- --------- ---------
#  1.054e-01 1.081e-01  1.110e-01 1.045e-01 1.933e-04 -4.857e-17 0.000e+00 8.000e-01 0.000e+00 2.000e+00
#  1.110e-01 1.118e-01  1.165e-01 1.034e-01 1.777e-05 -2.776e-17 1.963e-17 8.000e-01 0.000e+00 2.000e+00
#  1.667e-01 1.704e-01  1.723e-01 9.052e-02 2.053e-04 -2.776e-17 1.179e-17 8.000e-01 0.000e+00 3.000e+00
#  1.779e-01 1.800e-01  1.835e-01 8.884e-02 9.369e-05 -4.337e-17 1.227e-18 8.000e-01 0.000e+00 2.000e+00
#  2.058e-01 2.089e-01  2.113e-01 8.424e-02 1.262e-04 -1.908e-17 1.349e-17 8.000e-01 0.000e+00 2.000e+00
#  2.169e-01 2.196e-01  2.225e-01 8.270e-02 2.879e-05 -1.735e-17 1.717e-17 8.000e-01 0.000e+00 2.000e+00
#  2.225e-01 2.260e-01  2.281e-01 8.180e-02 5.956e-05 -3.782e-17 7.601e-19 8.000e-01       nan 5.000e+00
#  2.448e-01 2.455e-01  2.504e-01 7.921e-02 2.891e-05 -3.773e-17 3.067e-19 8.000e-01 0.000e+00 2.000e+00
#  2.504e-01 2.512e-01  2.560e-01 7.849e-02 5.093e-05 -2.544e-17 1.039e-17 8.000e-01 0.000e+00 3.000e+00
#  2.560e-01 2.585e-01  2.615e-01 7.758e-02 1.266e-04 -2.197e-17 9.300e-18 8.000e-01 0.000e+00 3.000e+00
#        ...       ...        ...       ...       ...        ...       ...       ...       ...       ...
#  5.426e+00 5.429e+00  5.431e+00 5.263e-03 1.078e-06 -1.753e-18 7.381e-19 8.000e-01 0.000e+00 3.000e+00
#  5.431e+00 5.435e+00  5.437e+00 5.255e-03 1.362e-06 -1.274e-18 9.008e-19 8.000e-01 0.000e+00 2.000e+00
#  5.443e+00 5.443e+00  5.448e+00 5.245e-03 8.106e-08 -1.308e-18 9.152e-19 8.000e-01 0.000e+00 2.000e+00
#  5.454e+00 5.455e+00  5.459e+00 5.228e-03 9.095e-07 -2.643e-18 4.792e-20 8.000e-01 0.000e+00 2.000e+00
#  5.459e+00 5.462e+00  5.465e+00 5.220e-03 1.396e-06 -2.539e-18 7.377e-21 8.000e-01 0.000e+00 3.000e+00
#  5.465e+00 5.466e+00  5.470e+00 5.214e-03 7.114e-07 -2.548e-18 0.000e+00 8.000e-01 0.000e+00 2.000e+00
#  5.470e+00 5.472e+00  5.476e+00 5.207e-03 1.043e-06 -1.287e-18 9.104e-19 8.000e-01 0.000e+00 2.000e+00
#  5.504e+00 5.505e+00  5.509e+00 5.164e-03 1.905e-07 -2.521e-18 1.917e-20 8.000e-01 0.000e+00 2.000e+00
#  5.515e+00 5.520e+00  5.521e+00 5.145e-03 1.277e-07 -2.521e-18 3.833e-20 8.000e-01 0.000e+00 2.000e+00
#  5.543e+00 5.544e+00  5.548e+00 5.114e-03 3.631e-07 -1.247e-18 8.816e-19 8.000e-01 0.000e+00 2.000e+00
#  5.576e+00 5.579e+00  5.582e+00 5.070e-03 1.757e-06 -1.240e-18 8.769e-19 8.000e-01 0.000e+00 2.000e+00
# Length = 899 rows

# %%
## once cosmology is chosen! --> choose halo model

# choose halo model: 
### make sure passing mass as a float to clmm

def nfw_to_shear_profile(logm, profile_info):
    r, gt_profile, z_src_rbin = profile_info
    m = float(10.**logm)
    gt_model = clmm.compute_reduced_tangential_shear(
        r, m, concentration, cluster_z, z_src_rbin, cosmo,
        delta_mdef=200, halo_profile_model='nfw')
    return np.sum((gt_model - gt_profile)**2)

# %%
###NOW MCMC!!

# %%
nfw_to_shear_profile(15,[cl.profile['radius'], cl.profile['gt'], cl.profile['z']])
# Out:
# 9.854242498297664e-12

# %%
clrad = cl.profile['radius']
clgt = cl.profile['gt']
clz = cl.profile['z']

# %%
# %%time

chisq = []

for i in range(9,25):
    chisq.append(nfw_to_shear_profile(i,[clrad, clgt, clz]))

    ### to save time, set profile info one time instead of re-calling
# Out:
# CPU times: user 63.4 ms, sys: 4 ms, total: 67.4 ms
# Wall time: 65.8 ms

# %%
plt.plot(range(9,25),np.log(chisq))

# %%
## add in the mass-concentration relationship!

from pyccl.halos.concentration import Concentration as conc

from pyccl.halos.massdef import MassDef200c as m200c

# %%
### m = fit mass (m200c); c = concentration (c200c)

# %%
r, gt_profile, z_src_rbin = cl.profile['radius'], cl.profile['gt'], cl.profile['z']

# %%
def emcee_logprior(params):
    logm = params
    if not 14 < logm < 15.57:
        return -np.inf
    return 0.0

### log mass MUST BE between 14 and 15.57 --> mass must be between 1.e14 and ~3.e15

def emcee_loglike(logm):
    m = float(10.*logm)
    gt_model = clmm.compute_reduced_tangential_shear(
        r, m, concentration, cluster_z, z_src_rbin, cosmo,
        delta_mdef=200, halo_profile_model='nfw')
    return np.sum((gt_model - gt_profile)**2)

### r, concentration, cluster_z, z_src_rbin, cosmo all known / fully-established perfectly

def emcee_logprob(params):
    lp = emcee_logprior(params)
    if not np.isfinite(lp):
        return -np.inf
    return lp + emcee_loglike(params)

# %%
# starting points for the chains
np.random.seed(9281)

nwalkers = 100
npar = 1

starts = np.array([14.5])
starts = starts + 0.1 * np.random.randn(nwalkers, npar)

# %%
nsteps_burn, nsteps_per_chain = 500, 2000

# set up the sampler
sampler = emcee.EnsembleSampler(nwalkers, npar, emcee_logprob)
# burn-in
print('## burning in ... ')
pos, prob, stat = sampler.run_mcmc(starts, nsteps_burn, progress=True)
# now reset the sampler
sampler.reset()
# run the full chain now
print('## running the full chain ... ')
sampler.run_mcmc(pos, nsteps_per_chain, progress=True);
# Out:
# ## burning in ...
# WARNING:emcee.pbar:You must install the tqdm library to use progress indicators with emcee
# ## running the full chain ...
# WARNING:emcee.pbar:You must install the tqdm library to use progress indicators with emcee

# %%
truths = [15.0]
param_labels = ['log(m)']

emcee_samples = sampler.get_chain(flat=True)

print(f'truths = {truths}')
plt.clf()
# set up the object
c = ChainConsumer()
# add chain
c.add_chain(emcee_samples, parameters=param_labels)
c.configure(statistics='max', summary=True,
            label_font_size=20, tick_font_size=16,
            usetex=False, serif=False,
            #max_ticks=5, kde=True
            #sigmas=[0,1,2,3,4,5]
            )
fig = c.plotter.plot(truth=truths,
                     #extents=[(-10, 10), (-10, 10), (-10, 10)],
                     parameters=param_labels,
                     figsize=(3*npar, 3*npar))
ax_list = fig.axes
for ax in ax_list: ax.grid(False)

plt.show();
# Out:
# WARNING:chainconsumer:Parameter log(m) in chain Chain 0 is not constrained
# truths = [15.0]

# %%
chain = sampler.get_chain()

fig, axes = plt.subplots(npar, 1)
plt.subplots_adjust(wspace=0.2, hspace=0.3)

for i in range(npar):
    ax = axes
    # plot the chain
    ax.plot(chain[:, :, i])
    xmax = len(chain[:, i])
    # truths
    ax.plot([0-100, xmax+100], [ truths[i], truths[i] ], 'k-.', lw=2, label='truth' )
    # starts
    ax.plot([0], [ starts[:, i] ], 'x', color='#d62728' )
    
    ax.set_ylabel(r'%s' % param_labels[i])

axes.legend(bbox_to_anchor=(1, 1))
axes.set_xlabel('# of steps')

fig.set_size_inches(10, 6*npar/3)

# %%
plt.clf()
c.configure_truth(**{'color': 'red'}) #, 'linewidth': '2'})
fig = c.plotter.plot_walks(convolve=100, truth=truths)
fig.set_size_inches(2*npar, 2*npar)
plt.show()

# %%
plt.clf()
fig, axes = plt.subplots(2, 1)
plt.subplots_adjust(wspace=0.2, hspace=0.3)

ax = axes[0]
ax.plot(sampler.get_log_prob(), '.-')
ax.plot(np.max( sampler.get_log_prob(), axis=1), 'k-.', label='max')
ax.legend()
ax.set_xlabel('# of steps')
ax.set_ylabel('log prob')
#ax.set_yscale('log')

ax = axes[1]
ax.plot(np.max( sampler.get_log_prob(), axis=0), '.-')
ax.set_xlabel('walker #')
ax.set_ylabel('max log prob')

plt.show()

# %%
x0 = np.linspace(-6, 6, 100)
lines = emcee_samples[:, 0] * x0[:, None] + emcee_samples[:, 1]
q = np.percentile(lines, [16, 50, 84], axis=1)
plt.fill_between(x0, q[0], q[2], color="C0", alpha=0.3)
plt.plot(x0, q[1], color="C0")
plt.xlim(-6, 6)

plt.plot(x, y, ".k")
plt.xlabel("x")
plt.ylabel("y");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 x0 = np.linspace(-6, 6, 100)
# ----> 2 lines = emcee_samples[:, 0] * x0[:, None] + emcee_samples[:, 1]
#       3 q = np.percentile(lines, [16, 50, 84], axis=1)
#       4 plt.fill_between(x0, q[0], q[2], color="C0", alpha=0.3)
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
